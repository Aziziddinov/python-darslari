# %%
import numpy as np
print(np.__version__)
# Out:
# 2.4.1

# %%
import pandas as pd
print(pd.__version__)
# Out:
# 2.3.3

# %%
from pandas import Series

# %%
obj = Series([4, 5, 6, 6-5])

# %%
type(obj)
# Out:
# pandas.core.series.Series

# %%
print(obj)
# Out:
# 0    4
# 1    5
# 2    6
# 3    1
# dtype: int64

# %%
obj.values
# Out:
# array([4, 5, 6, 1])

# %%
obj.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
obj[0]
# Out:
# np.int64(4)

# %%
obj2=Series([6, 3, 2, 1], index=['a', 'b', 'c', 'd'])

# %%
obj2
# Out:
# a    6
# b    3
# c    2
# d    1
# dtype: int64

# %%
obj2.index
# Out:
# Index(['a', 'b', 'c', 'd'], dtype='object')

# %%
obj2['a']
# Out:
# np.int64(6)

# %%
obj2['c']
# Out:
# np.int64(2)

# %%
obj2[['a', 'b', 'c']]
# Out:
# a    6
# b    3
# c    2
# dtype: int64

# %%
obj2[['a', 'a', 'a']]
# Out:
# a    6
# a    6
# a    6
# dtype: int64

# %%
obj2['b']
# Out:
# np.int64(3)

# %%
obj2[obj2>1]
# Out:
# a    6
# b    3
# c    2
# dtype: int64

# %%
obj2*2
# Out:
# a    12
# b     6
# c     4
# d     2
# dtype: int64

# %%
obj2
# Out:
# a    6
# b    3
# c    2
# d    1
# dtype: int64

# %%
np.exp(obj2)
# Out:
# a    403.428793
# b     20.085537
# c      7.389056
# d      2.718282
# dtype: float64

# %%
obj2['a']
# Out:
# np.int64(6)

# %%
obj2
# Out:
# a    6
# b    3
# c    2
# d    1
# dtype: int64

# %%
cars_dict = {
    'Malibu':40000, 'Lacetti':20000,
    'Toyota':45000, 'Mazda':52000, 'Honda':38000
      }

# %%
type(cars_dict)
# Out:
# dict

# %%
cars1 = Series(cars_dict)

# %%
cars1
# Out:
# Malibu     40000
# Lacetti    20000
# Toyota     45000
# Mazda      52000
# Honda      38000
# dtype: int64

# %%
type(cars1)
# Out:
# pandas.core.series.Series

# %%
cars1 = Series({
    'Malibu':40000, 'Lacetti':20000,
    'Toyota':45000, 'Mazda':52000, 'Honda':38000
      })

# %%
cars1
# Out:
# Malibu     40000
# Lacetti    20000
# Toyota     45000
# Mazda      52000
# Honda      38000
# dtype: int64

# %%
'Malibu' in cars1
# Out:
# True

# %%
'BMW' in cars1
# Out:
# False

# %%
cars1['Toyota']
# Out:
# np.int64(45000)

# %%
cars_dict
# Out:
# {'Malibu': 40000,
#  'Lacetti': 20000,
#  'Toyota': 45000,
#  'Mazda': 52000,
#  'Honda': 38000}

# %%
models = ['Honda', 'Mazda', 'Lacetti', 'Jaguar', 'Malibu', 'Toyota']

# %%
cars2 = Series(cars_dict, index=models)

# %%
cars2
# Out:
# Honda      38000.0
# Mazda      52000.0
# Lacetti    20000.0
# Jaguar         NaN
# Malibu     40000.0
# Toyota     45000.0
# dtype: float64
