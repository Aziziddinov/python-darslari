# %%
import numpy as np
import pandas as pd

# %%
data = {
    'Name': ['Alice', 'Bob', 'Charlie', 'David'],
    'Age': [24, 27, 22, 32],
    'City': ['New York', 'Los Angeles', 'Chicago', 'Houston']
}
df = pd.DataFrame(data)

# %%
df
# Out:
#       Name  Age         City
# 0    Alice   24     New York
# 1      Bob   27  Los Angeles
# 2  Charlie   22      Chicago
# 3    David   32      Houston

# %%
df.head()
# Out:
#       Name  Age         City
# 0    Alice   24     New York
# 1      Bob   27  Los Angeles
# 2  Charlie   22      Chicago
# 3    David   32      Houston

# %%
df.head(3)
# Out:
#       Name  Age         City
# 0    Alice   24     New York
# 1      Bob   27  Los Angeles
# 2  Charlie   22      Chicago

# %%
df.shape
# Out:
# (4, 3)

# %%
df = pd.DataFrame(data, columns=['Name', 'Age', 'City', 'Country'])

# %%
df.head()
# Out:
#       Name  Age         City Country
# 0    Alice   24     New York     NaN
# 1      Bob   27  Los Angeles     NaN
# 2  Charlie   22      Chicago     NaN
# 3    David   32      Houston     NaN

# %%
df = pd.DataFrame(data, columns=['Name', 'Age', 'City', 'Country'], index=['a', 'b', 'c', 'd'])

# %%
df
# Out:
#       Name  Age         City Country
# a    Alice   24     New York     NaN
# b      Bob   27  Los Angeles     NaN
# c  Charlie   22      Chicago     NaN
# d    David   32      Houston     NaN

# %%
df['Name']
# Out:
# a      Alice
# b        Bob
# c    Charlie
# d      David
# Name: Name, dtype: object

# %%
name_column = df['Name']

# %%
name_column
# Out:
# a      Alice
# b        Bob
# c    Charlie
# d      David
# Name: Name, dtype: object

# %%
type(name_column)
# Out:
# pandas.core.series.Series

# %%
df.head()
# Out:
#       Name  Age         City Country
# a    Alice   24     New York     NaN
# b      Bob   27  Los Angeles     NaN
# c  Charlie   22      Chicago     NaN
# d    David   32      Houston     NaN

# %%
df.Age
# Out:
# a    24
# b    27
# c    22
# d    32
# Name: Age, dtype: int64

# %%
df
# Out:
#       Name  Age         City Country
# a    Alice   24     New York     NaN
# b      Bob   27  Los Angeles     NaN
# c  Charlie   22      Chicago     NaN
# d    David   32      Houston     NaN

# %%
df.Country = ['USA', 'USA', 'USA', 'USA']

# %%
df
# Out:
#       Name  Age         City Country
# a    Alice   24     New York     USA
# b      Bob   27  Los Angeles     USA
# c  Charlie   22      Chicago     USA
# d    David   32      Houston     USA

# %%
val = pd.Series([1700, 1800, 1750, 1600], index=['a', 'b', 'c', 'd'])
df['Salary'] = val

# %%
df
# Out:
#       Name  Age         City Country  Salary
# a    Alice   24     New York     USA    1700
# b      Bob   27  Los Angeles     USA    1800
# c  Charlie   22      Chicago     USA    1750
# d    David   32      Houston     USA    1600

# %%
val = [1700, 1800, 1750, 1600]
df.Salary = val

# %%
df
# Out:
#       Name  Age         City Country  Salary
# a    Alice   24     New York     USA    1700
# b      Bob   27  Los Angeles     USA    1800
# c  Charlie   22      Chicago     USA    1750
# d    David   32      Houston     USA    1600

# %%
df['1700+'] = df.Salary > 1700

# %%
df
# Out:
#       Name  Age         City Country  Salary  1700+
# a    Alice   24     New York     USA    1700  False
# b      Bob   27  Los Angeles     USA    1800   True
# c  Charlie   22      Chicago     USA    1750   True
# d    David   32      Houston     USA    1600  False

# %%
df['Name'][df['1700+']]
# Out:
# b        Bob
# c    Charlie
# Name: Name, dtype: object

# %%
df
# Out:
#       Name  Age         City Country  Salary  1700+
# a    Alice   24     New York     USA    1700  False
# b      Bob   27  Los Angeles     USA    1800   True
# c  Charlie   22      Chicago     USA    1750   True
# d    David   32      Houston     USA    1600  False

# %%
data = {
    'Uzbekistan':{2021: 100, 2022: 110, 2023: 120},
    'USA':{2021: 200, 2022: 210, 2023: 220},
    'Russia':{2021: 300, 2022: 310, 2023: 320}
}
df2 = pd.DataFrame(data)

# %%
df2
# Out:
#       Uzbekistan  USA  Russia
# 2021         100  200     300
# 2022         110  210     310
# 2023         120  220     320

# %%
df2.index.name = 'Year'
df2.columns.name = 'Country'
df2
# Out:
# Country  Uzbekistan  USA  Russia
# Year
# 2021            100  200     300
# 2022            110  210     310
# 2023            120  220     320

# %%
df2 = pd.DataFrame(data, index=[2021, 2022, 2023])

# %%
df2
# Out:
#       Uzbekistan  USA  Russia
# 2021         100  200     300
# 2022         110  210     310
# 2023         120  220     320

# %%
df2.T
# Out:
#             2021  2022  2023
# Uzbekistan   100   110   120
# USA          200   210   220
# Russia       300   310   320

# %%
df2.values
# Out:
# array([[100, 200, 300],
#        [110, 210, 310],
#        [120, 220, 320]])

# %%
arr = df2.values

# %%
arr
# Out:
# array([[100, 200, 300],
#        [110, 210, 310],
#        [120, 220, 320]])

# %%
type(arr)
# Out:
# numpy.ndarray

# %%
df2.index
# Out:
# Index([2021, 2022, 2023], dtype='int64')

# %%
df
# Out:
#       Name  Age         City Country  Salary  1700+
# a    Alice   24     New York     USA    1700  False
# b      Bob   27  Los Angeles     USA    1800   True
# c  Charlie   22      Chicago     USA    1750   True
# d    David   32      Houston     USA    1600  False

# %%
df.index
# Out:
# Index(['a', 'b', 'c', 'd'], dtype='object')

# %%
df.columns
# Out:
# Index(['Name', 'Age', 'City', 'Country', 'Salary', '1700+'], dtype='object')

# %%
indeks = df.columns

# %%
indeks
# Out:
# Index(['Name', 'Age', 'City', 'Country', 'Salary', '1700+'], dtype='object')

# %%
'Temp' in indeks
# Out:
# False

# %%
df2
# Out:
#       Uzbekistan  USA  Russia
# 2021         100  200     300
# 2022         110  210     310
# 2023         120  220     320

# %%
'Tajikistan' in df2.columns
# Out:
# False

# %%
'USA' in df2.columns
# Out:
# True

# %%
2021 in df2
# Out:
# False

# %%
indeks
# Out:
# Index(['Name', 'Age', 'City', 'Country', 'Salary', '1700+'], dtype='object')

# %%
indeks[0]
# Out:
# 'Name'

# %%
indeks[2:4]
# Out:
# Index(['City', 'Country'], dtype='object')

# %%
indeks[0]="qiymat"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[345], line 1
# ----> 1 indeks[0]="qiymat"
#
# File c:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:5383, in Index.__setitem__(self, key, value)
#    5381 @final
#    5382 def __setitem__(self, key, value) -> None:
# -> 5383     raise TypeError("Index does not support mutable operations")
#
# TypeError: Index does not support mutable operations

# %%
df
# Out:
#       Name  Age         City Country  Salary  1700+
# a    Alice   24     New York     USA    1700  False
# b      Bob   27  Los Angeles     USA    1800   True
# c  Charlie   22      Chicago     USA    1750   True
# d    David   32      Houston     USA    1600  False

# %%
usernames={"Bob": "bob123", "Alice": "alice_w", "Charlie": "charlie89", "David": "david_d"}
emails = {"Bob": "bob@example.com", "Alice": "alice@example.com", "Charlie": "charlie@example.com", "David": "david@example.com"}

data = {
    'Username': usernames,
    'Email': emails
}

df = pd.DataFrame(data)

# %%
df
# Out:
#           Username                Email
# Bob         bob123      bob@example.com
# Alice      alice_w    alice@example.com
# Charlie  charlie89  charlie@example.com
# David      david_d    david@example.com

# %%
df.index
# Out:
# Index(['Bob', 'Alice', 'Charlie', 'David'], dtype='object')

# %%
arr = ['Bob', 'Alice', 'Charlie', 'David']

# %%
arr[0]
# Out:
# 'Bob'

# %%
arr[3]
# Out:
# 'David'

# %%
arr[1]
# Out:
# 'Alice'

# %%
data2 = {
    'username':{"Bob": "bob123", "Alice": "alice_w", "Charlie": "charlie89", "David": "david_d"},
    'email':{"Bob": "bob@example.com", "Alice": "alice@example.com", "Charlie": "charlie@example.com", "David": "david@example.com"}
}

# %%
data2
# Out:
# {'username': {'Bob': 'bob123',
#   'Alice': 'alice_w',
#   'Charlie': 'charlie89',
#   'David': 'david_d'},
#  'email': {'Bob': 'bob@example.com',
#   'Alice': 'alice@example.com',
#   'Charlie': 'charlie@example.com',
#   'David': 'david@example.com'}}

# %%
df2 = pd.DataFrame(data2)
df2
# Out:
#           username                email
# Bob         bob123      bob@example.com
# Alice      alice_w    alice@example.com
# Charlie  charlie89  charlie@example.com
# David      david_d    david@example.com

# %%
newind = pd.Index(['Bob', 'Alice', 'Charlie', 'David'])
newind
# Out:
# Index(['Bob', 'Alice', 'Charlie', 'David'], dtype='object')

# %%
newind.isin(['Alice', 'David'])
# Out:
# array([False,  True, False,  True])

# %%
df2.index.difference(newind)
# Out:
# Index([], dtype='object')

# %%
newind.difference(df2.index)
# Out:
# Index([], dtype='object')

# %%
df2.index.union(newind)
# Out:
# Index(['Bob', 'Alice', 'Charlie', 'David'], dtype='object')

# %%
df2.index.delete(0)
# Out:
# Index(['Alice', 'Charlie', 'David'], dtype='object')

# %%
newind
# Out:
# Index(['Bob', 'Alice', 'Charlie', 'David'], dtype='object')
